# %%
client_id = ''
client_secret = ''

# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = "https://accounts.spotify.com/api/token"
    
    def __init__(self, client_id, client_secret, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_client_credentials(self):
        """
        RETURNS A BASE 64 ENCODE STRING
        """
        client_id = self.client_id
        client_secret = self.client_secret
        if client_id == None or client_secret == None:
            raise Exception("TOU MUST SET client_id AND client_secret")
        client_creds= f"{client_id}:{client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return client_creds_b64.decode()
        
    def get_token_headers(self):
        client_creds_b64 = self.get_client_credentials()
        return {
            "Authorization": f"Basic {client_creds_b64}"
        }
    
    def get_token_data(self):
        return {
            "grant_type": "client_credentials"
        }
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        # print(r.json())
        if r.status_code not in range(200, 299):
            raise Exception("COULD NOT AUTHENTICATE CLIENTE")
            # return False
        data = r.json()
        now = datetime.datetime.now()
        access_token = data['access_token']
        expires_in = data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        # print(f"access_token -> {access_token}")
        # print(f"now -> {now}")
        # print(f"expires_in -> {expires_in}")
        # print(f"expires -> {expires}")
        return True
    
    def get_access_token(self):
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, lookup_id, resource_type="albums", version="v1"):
        endpoint = f"https://api.spotify.com/{version}/{resource_type}/{lookup_id}"
        print(f"endpoint -> {endpoint}")
        headers = self.get_resource_header()
        print(f"headers -> {headers}")
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200, 299):
            print(r.status_code)
            return {}
        print(r.status_code)
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type="albums")
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type="artists")
    
    def search(self, query, search_type="artist"):
        headers = self.get_resource_header()
        endpoint_search = "https://api.spotify.com/v1/search"
        data = urlencode({"q": query, "type": search_type.lower()})
        print(data)
        lookup_url = f"{endpoint_search}?{data}"
        print(lookup_url)
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200, 299):
            return {}
        print(r.status_code)
        return r.json()

# %%
spotify = SpotifyAPI(client_id, client_secret)

# %%
spotify.search("Hipnotizame", search_type="Track")
# Out:
# q=Hipnotizame&type=track
# https://api.spotify.com/v1/search?q=Hipnotizame&type=track
# 200
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Hipnotizame&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wZtkThiXbVNtj6hee6dz9'},
#        'href': 'https://api.spotify.com/v1/artists/1wZtkThiXbVNtj6hee6dz9',
#        'id': '1wZtkThiXbVNtj6hee6dz9',
#        'name': 'Wisin & Yandel',
#        'type': 'artist',
#        'uri': 'spotify:artist:1wZtkThiXbVNtj6hee6dz9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AM',
#       'AR',
#       'AT',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BF',
#       'BH',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DM',
#       'DO',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GD',
#       'GH',
#       'GM',
#       'GN',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IL',
#       'IN',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LI',
#       'LK',
#       'LT',
#       'LV',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MN',
#       'MO',
#       'MT',
#       'MU',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NP',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'SZ',
#       'TD',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VN',
#       'XK',
#       'ZA',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6tOFRRXAis3nniv1wG6Nae'},
#      'href': 'https://api.spotify.com/v1/albums/6tOFRRXAis3nniv1wG6Nae',
#      'id': '6tOFRRXAis3nniv1wG6Nae',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2736be6ef1173c9a2bb6705981c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e026be6ef1173c9a2bb6705981c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048516be6ef1173c9a2bb6705981c',
#        'width': 64}],
#      'name': 'Líderes',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:6tOFRRXAis3nniv1wG6Nae'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wZtkThiXbVNtj6hee6dz9'},
#       'href': 'https://api.spotify.com/v1/artists/1wZtkThiXbVNtj6hee6dz9',
#       'id': '1wZtkThiXbVNtj6hee6dz9',
#       'name': 'Wisin & Yandel',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wZtkThiXbVNtj6hee6dz9'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AM',
#      'AR',
#      'AT',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BF',
#      'BH',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DM',
#      'DO',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GD',
#      'GH',
#      'GM',
#      'GN',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IL',
#      'IN',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LI',
#      'LK',
#      'LT',
#      'LV',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MN',
#      'MO',
#      'MT',
#      'MU',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NP',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'SZ',
#      'TD',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VN',
#      'XK',
#      'ZA',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 243386,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71206368'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/41IrY9OFcaWVnEojXftyVh'},
#     'href': 'https://api.spotify.com/v1/tracks/41IrY9OFcaWVnEojXftyVh',
#     'id': '41IrY9OFcaWVnEojXftyVh',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'popularity': 62,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:41IrY9OFcaWVnEojXftyVh'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#        'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#        'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#        'name': 'Fobia',
#        'type': 'artist',
#        'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#      'available_markets': ['AG',
#       'AR',
#       'BB',
#       'BO',
#       'BR',
#       'BS',
#       'BZ',
#       'CL',
#       'CO',
#       'CR',
#       'CW',
#       'DM',
#       'DO',
#       'EC',
#       'GD',
#       'GT',
#       'GY',
#       'HN',
#       'HT',
#       'JM',
#       'KN',
#       'LC',
#       'MX',
#       'NI',
#       'PA',
#       'PE',
#       'PY',
#       'SR',
#       'SV',
#       'TT',
#       'US',
#       'UY',
#       'VC'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1oNccmu6KxWyQnGi9P7g5u'},
#      'href': 'https://api.spotify.com/v1/albums/1oNccmu6KxWyQnGi9P7g5u',
#      'id': '1oNccmu6KxWyQnGi9P7g5u',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731bb1c32a8aa6c69d4d882642',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021bb1c32a8aa6c69d4d882642',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511bb1c32a8aa6c69d4d882642',
#        'width': 64}],
#      'name': 'Amor Chiquito',
#      'release_date': '1996',
#      'release_date_precision': 'year',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1oNccmu6KxWyQnGi9P7g5u'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 207600,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF019501832'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7qHyrmULvIEtblpdClGzPi'},
#     'href': 'https://api.spotify.com/v1/tracks/7qHyrmULvIEtblpdClGzPi',
#     'id': '7qHyrmULvIEtblpdClGzPi',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b3125a51060eea5e416517d26cea20fa6a4b3329?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7qHyrmULvIEtblpdClGzPi'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1AUlEt0tp4Tiu9jcVraQwk'},
#        'href': 'https://api.spotify.com/v1/artists/1AUlEt0tp4Tiu9jcVraQwk',
#        'id': '1AUlEt0tp4Tiu9jcVraQwk',
#        'name': 'Sange',
#        'type': 'artist',
#        'uri': 'spotify:artist:1AUlEt0tp4Tiu9jcVraQwk'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6lBqDFnvjOR0Sde6pDnecC'},
#      'href': 'https://api.spotify.com/v1/albums/6lBqDFnvjOR0Sde6pDnecC',
#      'id': '6lBqDFnvjOR0Sde6pDnecC',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bb8dab4a4a0cc11debfc6a98',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bb8dab4a4a0cc11debfc6a98',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bb8dab4a4a0cc11debfc6a98',
#        'width': 64}],
#      'name': 'Hipnotízame',
#      'release_date': '2018-06-22',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6lBqDFnvjOR0Sde6pDnecC'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1AUlEt0tp4Tiu9jcVraQwk'},
#       'href': 'https://api.spotify.com/v1/artists/1AUlEt0tp4Tiu9jcVraQwk',
#       'id': '1AUlEt0tp4Tiu9jcVraQwk',
#       'name': 'Sange',
#       'type': 'artist',
#       'uri': 'spotify:artist:1AUlEt0tp4Tiu9jcVraQwk'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 201952,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZDA51855165'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3kRMiBabYTYU3PO2evoMbS'},
#     'href': 'https://api.spotify.com/v1/tracks/3kRMiBabYTYU3PO2evoMbS',
#     'id': '3kRMiBabYTYU3PO2evoMbS',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/86b03a8ce812c8bdba73bf0f0a74e1aad891ed54?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3kRMiBabYTYU3PO2evoMbS'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#        'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#        'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#        'name': 'Fobia',
#        'type': 'artist',
#        'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1wN4DxsgX1ReLLI3ZOmdEu'},
#      'href': 'https://api.spotify.com/v1/albums/1wN4DxsgX1ReLLI3ZOmdEu',
#      'id': '1wN4DxsgX1ReLLI3ZOmdEu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fb32d78286cc241d52648e6c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fb32d78286cc241d52648e6c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fb32d78286cc241d52648e6c',
#        'width': 64}],
#      'name': 'Fobia MTV Unplugged',
#      'release_date': '2020-12-18',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:1wN4DxsgX1ReLLI3ZOmdEu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 222659,
#     'explicit': False,
#     'external_ids': {'isrc': 'MX1722001264'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3FwCOGTG2sGmcTGU2GqM2N'},
#     'href': 'https://api.spotify.com/v1/tracks/3FwCOGTG2sGmcTGU2GqM2N',
#     'id': '3FwCOGTG2sGmcTGU2GqM2N',
#     'is_local': False,
#     'name': 'Hipnotízame - MTV Unplugged',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a5730e1bdec20d36b45e5248c5bbdb6525b6404c?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:3FwCOGTG2sGmcTGU2GqM2N'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3iuDJzaIhy7gDPgmUW2ujw'},
#        'href': 'https://api.spotify.com/v1/artists/3iuDJzaIhy7gDPgmUW2ujw',
#        'id': '3iuDJzaIhy7gDPgmUW2ujw',
#        'name': 'Fumaratto',
#        'type': 'artist',
#        'uri': 'spotify:artist:3iuDJzaIhy7gDPgmUW2ujw'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/66OBjU5X4edaRBuNZHaZYV'},
#      'href': 'https://api.spotify.com/v1/albums/66OBjU5X4edaRBuNZHaZYV',
#      'id': '66OBjU5X4edaRBuNZHaZYV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730ce94c071a4b223e6419e2ba',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020ce94c071a4b223e6419e2ba',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510ce94c071a4b223e6419e2ba',
#        'width': 64}],
#      'name': 'Origenes',
#      'release_date': '2021-01-15',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:66OBjU5X4edaRBuNZHaZYV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3iuDJzaIhy7gDPgmUW2ujw'},
#       'href': 'https://api.spotify.com/v1/artists/3iuDJzaIhy7gDPgmUW2ujw',
#       'id': '3iuDJzaIhy7gDPgmUW2ujw',
#       'name': 'Fumaratto',
#       'type': 'artist',
#       'uri': 'spotify:artist:3iuDJzaIhy7gDPgmUW2ujw'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5Fw4n5XRnte30eKCBAdwWH'},
#       'href': 'https://api.spotify.com/v1/artists/5Fw4n5XRnte30eKCBAdwWH',
#       'id': '5Fw4n5XRnte30eKCBAdwWH',
#       'name': 'Dj Flechas',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Fw4n5XRnte30eKCBAdwWH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 205997,
#     'explicit': False,
#     'external_ids': {'isrc': 'ESA011641389'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4uXUXS2JL82PBFXPIRSCeY'},
#     'href': 'https://api.spotify.com/v1/tracks/4uXUXS2JL82PBFXPIRSCeY',
#     'id': '4uXUXS2JL82PBFXPIRSCeY',
#     'is_local': False,
#     'name': 'Hipnotizame',
#     'popularity': 22,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3393fd494b0892ee2acb3afff28e298c4ba03705?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 17,
#     'type': 'track',
#     'uri': 'spotify:track:4uXUXS2JL82PBFXPIRSCeY'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wZtkThiXbVNtj6hee6dz9'},
#        'href': 'https://api.spotify.com/v1/artists/1wZtkThiXbVNtj6hee6dz9',
#        'id': '1wZtkThiXbVNtj6hee6dz9',
#        'name': 'Wisin & Yandel',
#        'type': 'artist',
#        'uri': 'spotify:artist:1wZtkThiXbVNtj6hee6dz9'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0loA0jfaqDK2UYK6iICSp3'},
#      'href': 'https://api.spotify.com/v1/albums/0loA0jfaqDK2UYK6iICSp3',
#      'id': '0loA0jfaqDK2UYK6iICSp3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb02827979ad30066119b41a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb02827979ad30066119b41a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb02827979ad30066119b41a',
#        'width': 64}],
#      'name': 'Líderes (Muve Sessions)',
#      'release_date': '2012-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:0loA0jfaqDK2UYK6iICSp3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wZtkThiXbVNtj6hee6dz9'},
#       'href': 'https://api.spotify.com/v1/artists/1wZtkThiXbVNtj6hee6dz9',
#       'id': '1wZtkThiXbVNtj6hee6dz9',
#       'name': 'Wisin & Yandel',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wZtkThiXbVNtj6hee6dz9'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 243386,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71206368'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4NRXbIdzDdHKwpB19PKex7'},
#     'href': 'https://api.spotify.com/v1/tracks/4NRXbIdzDdHKwpB19PKex7',
#     'id': '4NRXbIdzDdHKwpB19PKex7',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'popularity': 10,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4NRXbIdzDdHKwpB19PKex7'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#        'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#        'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#        'name': 'Fobia',
#        'type': 'artist',
#        'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/08eN1GFr5VWVFcPEJL9TOu'},
#      'href': 'https://api.spotify.com/v1/albums/08eN1GFr5VWVFcPEJL9TOu',
#      'id': '08eN1GFr5VWVFcPEJL9TOu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eba5ea1c1710bbda32eb7b93',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eba5ea1c1710bbda32eb7b93',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eba5ea1c1710bbda32eb7b93',
#        'width': 64}],
#      'name': 'Pastel (En Vivo)',
#      'release_date': '2019-03-01',
#      'release_date_precision': 'day',
#      'total_tracks': 32,
#      'type': 'album',
#      'uri': 'spotify:album:08eN1GFr5VWVFcPEJL9TOu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 211800,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF011800575'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2mD9ecy5SdkOq0sZKbDLMq'},
#     'href': 'https://api.spotify.com/v1/tracks/2mD9ecy5SdkOq0sZKbDLMq',
#     'id': '2mD9ecy5SdkOq0sZKbDLMq',
#     'is_local': False,
#     'name': 'Hipnotízame - Pastel - En Vivo',
#     'popularity': 24,
#     'preview_url': 'https://p.scdn.co/mp3-preview/1cfa96ed001ce945e3fb7298c2866aea22dc91b5?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 28,
#     'type': 'track',
#     'uri': 'spotify:track:2mD9ecy5SdkOq0sZKbDLMq'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#        'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#        'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#        'name': 'Fobia',
#        'type': 'artist',
#        'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5iFWpLPhibMjK3Zk4CO19q'},
#      'href': 'https://api.spotify.com/v1/albums/5iFWpLPhibMjK3Zk4CO19q',
#      'id': '5iFWpLPhibMjK3Zk4CO19q',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730f5a660eb52b41c12b17d920',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020f5a660eb52b41c12b17d920',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510f5a660eb52b41c12b17d920',
#        'width': 64}],
#      'name': 'Fobia - XX',
#      'release_date': '2007-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:5iFWpLPhibMjK3Zk4CO19q'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 222106,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF010600561'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/03SbiOByEjzcm7az7Y8uMr'},
#     'href': 'https://api.spotify.com/v1/tracks/03SbiOByEjzcm7az7Y8uMr',
#     'id': '03SbiOByEjzcm7az7Y8uMr',
#     'is_local': False,
#     'name': 'Hipnotizame - En Vivo',
#     'popularity': 19,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5b652e2a1d6b52c67631560ae200af0396555599?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:03SbiOByEjzcm7az7Y8uMr'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#        'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#        'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#        'name': 'Fobia',
#        'type': 'artist',
#        'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#      'available_markets': ['US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0aGusz7aHYnYfjWSTr1YFI'},
#      'href': 'https://api.spotify.com/v1/albums/0aGusz7aHYnYfjWSTr1YFI',
#      'id': '0aGusz7aHYnYfjWSTr1YFI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27303b0963d4d744f01f8138c46',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0203b0963d4d744f01f8138c46',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485103b0963d4d744f01f8138c46',
#        'width': 64}],
#      'name': 'Rock Latino',
#      'release_date': '2012-06-26',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0aGusz7aHYnYfjWSTr1YFI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['US'],
#     'disc_number': 1,
#     'duration_ms': 207320,
#     'explicit': False,
#     'external_ids': {'isrc': 'MXF019501832'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5jBKzSE0c0OuN4CNYYp5I9'},
#     'href': 'https://api.spotify.com/v1/tracks/5jBKzSE0c0OuN4CNYYp5I9',
#     'id': '5jBKzSE0c0OuN4CNYYp5I9',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'popularity': 6,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ca699f537f9f02ad213662ccf8ca8dfe605fb717?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:5jBKzSE0c0OuN4CNYYp5I9'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4FjrR49lRwdio2vojjo3k9'},
#        'href': 'https://api.spotify.com/v1/artists/4FjrR49lRwdio2vojjo3k9',
#        'id': '4FjrR49lRwdio2vojjo3k9',
#        'name': 'Min Shizou',
#        'type': 'artist',
#        'uri': 'spotify:artist:4FjrR49lRwdio2vojjo3k9'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6D9OTVhH1Qri918256OZ4d'},
#      'href': 'https://api.spotify.com/v1/albums/6D9OTVhH1Qri918256OZ4d',
#      'id': '6D9OTVhH1Qri918256OZ4d',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733bd1c4ea9426c7141a6ba242',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023bd1c4ea9426c7141a6ba242',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513bd1c4ea9426c7141a6ba242',
#        'width': 64}],
#      'name': 'Hipnotizame',
#      'release_date': '2021-06-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6D9OTVhH1Qri918256OZ4d'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4FjrR49lRwdio2vojjo3k9'},
#       'href': 'https://api.spotify.com/v1/artists/4FjrR49lRwdio2vojjo3k9',
#       'id': '4FjrR49lRwdio2vojjo3k9',
#       'name': 'Min Shizou',
#       'type': 'artist',
#       'uri': 'spotify:artist:4FjrR49lRwdio2vojjo3k9'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0gzwXezN4IUHAwLufA6YcX'},
#       'href': 'https://api.spotify.com/v1/artists/0gzwXezN4IUHAwLufA6YcX',
#       'id': '0gzwXezN4IUHAwLufA6YcX',
#       'name': 'Emma',
#       'type': 'artist',
#       'uri': 'spotify:artist:0gzwXezN4IUHAwLufA6YcX'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
# ...
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 213517,
#     'explicit': False,
#     'external_ids': {'isrc': 'ES71G1946094'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6lMe385D1B7hwE0OaWdLZI'},
#     'href': 'https://api.spotify.com/v1/tracks/6lMe385D1B7hwE0OaWdLZI',
#     'id': '6lMe385D1B7hwE0OaWdLZI',
#     'is_local': False,
#     'name': 'Hipnotizame',
#     'popularity': 6,
#     'preview_url': 'https://p.scdn.co/mp3-preview/697e7442ae7cb35526c34403c253c6c7f7a87d5c?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6lMe385D1B7hwE0OaWdLZI'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SN',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7iM6MQKvAj3f3VIpIocm52'},
#      'href': 'https://api.spotify.com/v1/albums/7iM6MQKvAj3f3VIpIocm52',
#      'id': '7iM6MQKvAj3f3VIpIocm52',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738cabf07e8410751d809fc47c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028cabf07e8410751d809fc47c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518cabf07e8410751d809fc47c',
#        'width': 64}],
#      'name': 'Mix Motivacional Vol. 2',
#      'release_date': '2021-03-12',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:7iM6MQKvAj3f3VIpIocm52'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wZtkThiXbVNtj6hee6dz9'},
#       'href': 'https://api.spotify.com/v1/artists/1wZtkThiXbVNtj6hee6dz9',
#       'id': '1wZtkThiXbVNtj6hee6dz9',
#       'name': 'Wisin & Yandel',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wZtkThiXbVNtj6hee6dz9'}],
#     'available_markets': ['AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SN',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 243386,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71206368'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Tnu4DaBZ1s1k7PoIkEdc5'},
#     'href': 'https://api.spotify.com/v1/tracks/3Tnu4DaBZ1s1k7PoIkEdc5',
#     'id': '3Tnu4DaBZ1s1k7PoIkEdc5',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'popularity': 6,
#     'preview_url': None,
#     'track_number': 26,
#     'type': 'track',
#     'uri': 'spotify:track:3Tnu4DaBZ1s1k7PoIkEdc5'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/34B8ezxmfzE7STZdxZNAUB'},
#        'href': 'https://api.spotify.com/v1/artists/34B8ezxmfzE7STZdxZNAUB',
#        'id': '34B8ezxmfzE7STZdxZNAUB',
#        'name': 'Signuz',
#        'type': 'artist',
#        'uri': 'spotify:artist:34B8ezxmfzE7STZdxZNAUB'}],
#      'available_markets': ['AD',
#       'AE',
#       'AG',
#       'AL',
#       'AM',
#       'AO',
#       'AR',
#       'AT',
#       'AU',
#       'AZ',
#       'BA',
#       'BB',
#       'BD',
#       'BE',
#       'BF',
#       'BG',
#       'BH',
#       'BI',
#       'BJ',
#       'BN',
#       'BO',
#       'BR',
#       'BS',
#       'BT',
#       'BW',
#       'BY',
#       'BZ',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CM',
#       'CO',
#       'CR',
#       'CV',
#       'CW',
#       'CY',
#       'CZ',
#       'DE',
#       'DJ',
#       'DK',
#       'DM',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FJ',
#       'FM',
#       'FR',
#       'GA',
#       'GB',
#       'GD',
#       'GE',
#       'GH',
#       'GM',
#       'GN',
#       'GQ',
#       'GR',
#       'GT',
#       'GW',
#       'GY',
#       'HK',
#       'HN',
#       'HR',
#       'HT',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JM',
#       'JO',
#       'JP',
#       'KE',
#       'KG',
#       'KH',
#       'KI',
#       'KM',
#       'KN',
#       'KR',
#       'KW',
#       'KZ',
#       'LA',
#       'LB',
#       'LC',
#       'LI',
#       'LK',
#       'LR',
#       'LS',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MG',
#       'MH',
#       'MK',
#       'ML',
#       'MN',
#       'MO',
#       'MR',
#       'MT',
#       'MU',
#       'MV',
#       'MW',
#       'MX',
#       'MY',
#       'MZ',
#       'NA',
#       'NE',
#       'NG',
#       'NI',
#       'NL',
#       'NO',
#       'NP',
#       'NR',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PG',
#       'PH',
#       'PK',
#       'PL',
#       'PS',
#       'PT',
#       'PW',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'RW',
#       'SA',
#       'SB',
#       'SC',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SL',
#       'SM',
#       'SN',
#       'SR',
#       'ST',
#       'SV',
#       'SZ',
#       'TD',
#       'TG',
#       'TH',
#       'TL',
#       'TN',
#       'TO',
#       'TR',
#       'TT',
#       'TV',
#       'TW',
#       'TZ',
#       'UA',
#       'UG',
#       'US',
#       'UY',
#       'UZ',
#       'VC',
#       'VN',
#       'VU',
#       'WS',
#       'XK',
#       'ZA',
#       'ZM',
#       'ZW'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4FUALBVtH6nnCexWoDYnyl'},
#      'href': 'https://api.spotify.com/v1/albums/4FUALBVtH6nnCexWoDYnyl',
#      'id': '4FUALBVtH6nnCexWoDYnyl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ac1bba3209a686695bd5bd1f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ac1bba3209a686695bd5bd1f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ac1bba3209a686695bd5bd1f',
#        'width': 64}],
#      'name': '#1990',
#      'release_date': '2015-05-08',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:4FUALBVtH6nnCexWoDYnyl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/34B8ezxmfzE7STZdxZNAUB'},
#       'href': 'https://api.spotify.com/v1/artists/34B8ezxmfzE7STZdxZNAUB',
#       'id': '34B8ezxmfzE7STZdxZNAUB',
#       'name': 'Signuz',
#       'type': 'artist',
#       'uri': 'spotify:artist:34B8ezxmfzE7STZdxZNAUB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AG',
#      'AL',
#      'AM',
#      'AO',
#      'AR',
#      'AT',
#      'AU',
#      'AZ',
#      'BA',
#      'BB',
#      'BD',
#      'BE',
#      'BF',
#      'BG',
#      'BH',
#      'BI',
#      'BJ',
#      'BN',
#      'BO',
#      'BR',
#      'BS',
#      'BT',
#      'BW',
#      'BY',
#      'BZ',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CM',
#      'CO',
#      'CR',
#      'CV',
#      'CW',
#      'CY',
#      'CZ',
#      'DE',
#      'DJ',
#      'DK',
#      'DM',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FJ',
#      'FM',
#      'FR',
#      'GA',
#      'GB',
#      'GD',
#      'GE',
#      'GH',
#      'GM',
#      'GN',
#      'GQ',
#      'GR',
#      'GT',
#      'GW',
#      'GY',
#      'HK',
#      'HN',
#      'HR',
#      'HT',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JM',
#      'JO',
#      'JP',
#      'KE',
#      'KG',
#      'KH',
#      'KI',
#      'KM',
#      'KN',
#      'KR',
#      'KW',
#      'KZ',
#      'LA',
#      'LB',
#      'LC',
#      'LI',
#      'LK',
#      'LR',
#      'LS',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MG',
#      'MH',
#      'MK',
#      'ML',
#      'MN',
#      'MO',
#      'MR',
#      'MT',
#      'MU',
#      'MV',
#      'MW',
#      'MX',
#      'MY',
#      'MZ',
#      'NA',
#      'NE',
#      'NG',
#      'NI',
#      'NL',
#      'NO',
#      'NP',
#      'NR',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PG',
#      'PH',
#      'PK',
#      'PL',
#      'PS',
#      'PT',
#      'PW',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'RW',
#      'SA',
#      'SB',
#      'SC',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SL',
#      'SM',
#      'SN',
#      'SR',
#      'ST',
#      'SV',
#      'SZ',
#      'TD',
#      'TG',
#      'TH',
#      'TL',
#      'TN',
#      'TO',
#      'TR',
#      'TT',
#      'TV',
#      'TW',
#      'TZ',
#      'UA',
#      'UG',
#      'US',
#      'UY',
#      'UZ',
#      'VC',
#      'VN',
#      'VU',
#      'WS',
#      'XK',
#      'ZA',
#      'ZM',
#      'ZW'],
#     'disc_number': 1,
#     'duration_ms': 280147,
#     'explicit': False,
#     'external_ids': {'isrc': 'FRX201588940'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/09HGDm8GR3gJE5h3KPb1Qo'},
#     'href': 'https://api.spotify.com/v1/tracks/09HGDm8GR3gJE5h3KPb1Qo',
#     'id': '09HGDm8GR3gJE5h3KPb1Qo',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'popularity': 7,
#     'preview_url': 'https://p.scdn.co/mp3-preview/9b1bb487163ed55aafa295a8809f58a257d38214?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:09HGDm8GR3gJE5h3KPb1Qo'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AE',
#       'AR',
#       'AU',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CI',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'ES',
#       'GB',
#       'GH',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IN',
#       'IT',
#       'JP',
#       'KE',
#       'KH',
#       'KR',
#       'KW',
#       'LB',
#       'LK',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MT',
#       'MX',
#       'MY',
#       'NG',
#       'NI',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TR',
#       'TT',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0CG0sbQHNtwdi96vE5KSWQ'},
#      'href': 'https://api.spotify.com/v1/albums/0CG0sbQHNtwdi96vE5KSWQ',
#      'id': '0CG0sbQHNtwdi96vE5KSWQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f19425e8bd89fcc788acedb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f19425e8bd89fcc788acedb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f19425e8bd89fcc788acedb',
#        'width': 64}],
#      'name': 'Costa Rica se queda en casa',
#      'release_date': '2020-04-03',
#      'release_date_precision': 'day',
#      'total_tracks': 27,
#      'type': 'album',
#      'uri': 'spotify:album:0CG0sbQHNtwdi96vE5KSWQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1wZtkThiXbVNtj6hee6dz9'},
#       'href': 'https://api.spotify.com/v1/artists/1wZtkThiXbVNtj6hee6dz9',
#       'id': '1wZtkThiXbVNtj6hee6dz9',
#       'name': 'Wisin & Yandel',
#       'type': 'artist',
#       'uri': 'spotify:artist:1wZtkThiXbVNtj6hee6dz9'}],
#     'available_markets': ['AE',
#      'AR',
#      'AU',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CI',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'ES',
#      'GB',
#      'GH',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IN',
#      'IT',
#      'JP',
#      'KE',
#      'KH',
#      'KR',
#      'KW',
#      'LB',
#      'LK',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MT',
#      'MX',
#      'MY',
#      'NG',
#      'NI',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TR',
#      'TT',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 242973,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71206368'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7nxd3OSgryDth3YHa0H7gW'},
#     'href': 'https://api.spotify.com/v1/tracks/7nxd3OSgryDth3YHa0H7gW',
#     'id': '7nxd3OSgryDth3YHa0H7gW',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'popularity': 7,
#     'preview_url': None,
#     'track_number': 24,
#     'type': 'track',
#     'uri': 'spotify:track:7nxd3OSgryDth3YHa0H7gW'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Hipnotizame&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 227}}

# %%
spotify.get_artist("3SqzxvGCKGJ9PYKXXPwjQS")
# Out:
# endpoint -> https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS
# headers -> {'Authorization': 'Bearer BQBtMlrwC_dp2m_OVgHH6c_CLLjq-SbCXoshjWvsCJX3JySDBMxP9TiEGK2Jfss5QylDiUs8MQoJin7wR3g'}
# 200
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#  'followers': {'href': None, 'total': 751193},
#  'genres': ['latin alternative',
#   'latin rock',
#   'mexican indie',
#   'mexican rock',
#   'rock en espanol'],
#  'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#  'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/de82d23c1d85a13533b5d1dc09952163f2960f0b',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/3e72ae7776316095756f6aaf06f501f8f4fa6e35',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/b7e1aea30e85edfa4a62c138462d3519c67d4458',
#    'width': 160}],
#  'name': 'Fobia',
#  'popularity': 62,
#  'type': 'artist',
#  'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}

# %%
spotify.get_album("1oNccmu6KxWyQnGi9P7g5u")
# Out:
# endpoint -> https://api.spotify.com/v1/albums/1oNccmu6KxWyQnGi9P7g5u
# headers -> {'Authorization': 'Bearer BQDH4T3LC4XByHuiOYqFpYfK6Hzs_NACxNnwaiCC_-ZW6nh6mzsOvShPl-83xScYuwQbLugLSEyEpXxlz6c'}
# 200
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#    'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#    'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#    'name': 'Fobia',
#    'type': 'artist',
#    'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#  'available_markets': ['AG',
#   'AR',
#   'BB',
#   'BO',
#   'BR',
#   'BS',
#   'BZ',
#   'CL',
#   'CO',
#   'CR',
#   'CW',
#   'DM',
#   'DO',
#   'EC',
#   'GD',
#   'GT',
#   'GY',
#   'HN',
#   'HT',
#   'JM',
#   'KN',
#   'LC',
#   'MX',
#   'NI',
#   'PA',
#   'PE',
#   'PY',
#   'SR',
#   'SV',
#   'TT',
#   'US',
#   'UY',
#   'VC'],
#  'copyrights': [{'text': '(P) 1995 Bertelsmann De Mexico, S.A. De C.V.',
#    'type': 'P'}],
#  'external_ids': {'upc': '743213288420'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/1oNccmu6KxWyQnGi9P7g5u'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/1oNccmu6KxWyQnGi9P7g5u',
#  'id': '1oNccmu6KxWyQnGi9P7g5u',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b2731bb1c32a8aa6c69d4d882642',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e021bb1c32a8aa6c69d4d882642',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d000048511bb1c32a8aa6c69d4d882642',
#    'width': 64}],
#  'label': 'Ariola',
#  'name': 'Amor Chiquito',
#  'popularity': 58,
#  'release_date': '1996',
#  'release_date_precision': 'year',
#  'total_tracks': 12,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/1oNccmu6KxWyQnGi9P7g5u/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 257693,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3t5ArO9LVDcg0vLUGVGjp7'},
#     'href': 'https://api.spotify.com/v1/tracks/3t5ArO9LVDcg0vLUGVGjp7',
#     'id': '3t5ArO9LVDcg0vLUGVGjp7',
#     'is_local': False,
#     'name': 'Revolución Sin Manos',
#     'preview_url': 'https://p.scdn.co/mp3-preview/dac9843873344501ba6140d7bc3f01a9f4ad2c1d?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3t5ArO9LVDcg0vLUGVGjp7'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 300026,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5SLBKNTAinO0L3d3zfmuQX'},
#     'href': 'https://api.spotify.com/v1/tracks/5SLBKNTAinO0L3d3zfmuQX',
#     'id': '5SLBKNTAinO0L3d3zfmuQX',
#     'is_local': False,
#     'name': 'Descontrol',
#     'preview_url': 'https://p.scdn.co/mp3-preview/67f9cfaa3d558b7d2601ced4f9f49f4e8cc38d6b?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:5SLBKNTAinO0L3d3zfmuQX'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 217906,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1qdvBrmrYmEfqu6NHeAF9x'},
#     'href': 'https://api.spotify.com/v1/tracks/1qdvBrmrYmEfqu6NHeAF9x',
#     'id': '1qdvBrmrYmEfqu6NHeAF9x',
#     'is_local': False,
#     'name': 'Vestida para Matar',
#     'preview_url': 'https://p.scdn.co/mp3-preview/3da3fb8be4bb9e8379bff27b3cab211e7c3d13c4?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1qdvBrmrYmEfqu6NHeAF9x'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 207600,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7qHyrmULvIEtblpdClGzPi'},
#     'href': 'https://api.spotify.com/v1/tracks/7qHyrmULvIEtblpdClGzPi',
#     'id': '7qHyrmULvIEtblpdClGzPi',
#     'is_local': False,
#     'name': 'Hipnotízame',
#     'preview_url': 'https://p.scdn.co/mp3-preview/b3125a51060eea5e416517d26cea20fa6a4b3329?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7qHyrmULvIEtblpdClGzPi'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 76266,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4PtDA8OumHtLm5l7dwwKoO'},
#     'href': 'https://api.spotify.com/v1/tracks/4PtDA8OumHtLm5l7dwwKoO',
#     'id': '4PtDA8OumHtLm5l7dwwKoO',
#     'is_local': False,
#     'name': 'Ai Kan Bugui',
#     'preview_url': 'https://p.scdn.co/mp3-preview/389d43cd27cb405792cd62271fb0acfcafdc9dbd?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4PtDA8OumHtLm5l7dwwKoO'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 297533,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7lBKa0oQnv6w2AgFiBqRW2'},
#     'href': 'https://api.spotify.com/v1/tracks/7lBKa0oQnv6w2AgFiBqRW2',
#     'id': '7lBKa0oQnv6w2AgFiBqRW2',
#     'is_local': False,
#     'name': 'Veneno Vil',
#     'preview_url': 'https://p.scdn.co/mp3-preview/7e2c9b5d891af009fb5bca182a16882f666f43b1?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7lBKa0oQnv6w2AgFiBqRW2'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 206933,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7dvye3RPN96bipIYvGaVPJ'},
#     'href': 'https://api.spotify.com/v1/tracks/7dvye3RPN96bipIYvGaVPJ',
#     'id': '7dvye3RPN96bipIYvGaVPJ',
#     'is_local': False,
#     'name': 'Mira Teté (Mientras Más Fumo Más Te Quiero)',
#     'preview_url': 'https://p.scdn.co/mp3-preview/ada15a314c2ec84466cb156f8b1260b36f8e5cc9?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7dvye3RPN96bipIYvGaVPJ'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 284960,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/024iRW1M37lZV0LWwalyhL'},
#     'href': 'https://api.spotify.com/v1/tracks/024iRW1M37lZV0LWwalyhL',
#     'id': '024iRW1M37lZV0LWwalyhL',
#     'is_local': False,
#     'name': 'Sin Querer',
#     'preview_url': 'https://p.scdn.co/mp3-preview/6f1698cacb53cb645aa8c3754748d869b1b59fdc?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:024iRW1M37lZV0LWwalyhL'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 204906,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4aZXL2gT6fGiqkOfmSWjBx'},
#     'href': 'https://api.spotify.com/v1/tracks/4aZXL2gT6fGiqkOfmSWjBx',
#     'id': '4aZXL2gT6fGiqkOfmSWjBx',
#     'is_local': False,
#     'name': 'Casi Amor',
#     'preview_url': 'https://p.scdn.co/mp3-preview/1796d4ab1ccca4a82431b745df0f456f00049de6?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:4aZXL2gT6fGiqkOfmSWjBx'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 283093,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5IfhLKhOBkHazqaoqFzH8G'},
#     'href': 'https://api.spotify.com/v1/tracks/5IfhLKhOBkHazqaoqFzH8G',
#     'id': '5IfhLKhOBkHazqaoqFzH8G',
#     'is_local': False,
#     'name': 'Vivo',
#     'preview_url': 'https://p.scdn.co/mp3-preview/2c4240ea4138300bfdf8c08a4c0353ff178be87b?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:5IfhLKhOBkHazqaoqFzH8G'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 254200,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ETJxKiwhokb7STAZlo6y4'},
#     'href': 'https://api.spotify.com/v1/tracks/6ETJxKiwhokb7STAZlo6y4',
#     'id': '6ETJxKiwhokb7STAZlo6y4',
#     'is_local': False,
#     'name': 'Casa Vacía',
#     'preview_url': 'https://p.scdn.co/mp3-preview/93ec7b05bcd6c33e0cc8e2dfdf1ebd3ea4a77335?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:6ETJxKiwhokb7STAZlo6y4'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3SqzxvGCKGJ9PYKXXPwjQS'},
#       'href': 'https://api.spotify.com/v1/artists/3SqzxvGCKGJ9PYKXXPwjQS',
#       'id': '3SqzxvGCKGJ9PYKXXPwjQS',
#       'name': 'Fobia',
#       'type': 'artist',
#       'uri': 'spotify:artist:3SqzxvGCKGJ9PYKXXPwjQS'}],
#     'available_markets': ['AG',
#      'AR',
#      'BB',
#      'BO',
#      'BR',
#      'BS',
#      'BZ',
#      'CL',
#      'CO',
#      'CR',
#      'CW',
#      'DM',
#      'DO',
#      'EC',
#      'GD',
#      'GT',
#      'GY',
#      'HN',
#      'HT',
#      'JM',
#      'KN',
#      'LC',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SR',
#      'SV',
#      'TT',
#      'US',
#      'UY',
#      'VC'],
#     'disc_number': 1,
#     'duration_ms': 67866,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7bWTGvh5kFZRdVnyKP4RPa'},
#     'href': 'https://api.spotify.com/v1/tracks/7bWTGvh5kFZRdVnyKP4RPa',
#     'id': '7bWTGvh5kFZRdVnyKP4RPa',
#     'is_local': False,
#     'name': 'Estrellas en la Panza',
#     'preview_url': 'https://p.scdn.co/mp3-preview/1f2cc548e85de0674e8e9f6b17316865adf2fa50?cid=6a5fed9a7d304efaa57e0684a3937719',
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:7bWTGvh5kFZRdVnyKP4RPa'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 12},
#  'type': 'album',
#  'uri': 'spotify:album:1oNccmu6KxWyQnGi9P7g5u'}
